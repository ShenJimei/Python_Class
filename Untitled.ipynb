# %% [markdown]
# # Jupyter Notebook的使用

# %%
print('岩哥颜值无敌')
# Out:
# 岩哥颜值无敌

# %% [markdown]
# ## 快捷键
# ![image.png](attachment:image.png)

# %% [markdown]
# # 魔法命令

# %% [markdown]
# ## -% run 后面跟一个地址

# %% [markdown]
# ### 加载模块

# %% [markdown]
# ### mport 文件夹名.文件名

# %% [markdown]
# ### from 文件夹名 import 文件名 as

# %% [markdown]
# ### 函数的注释查看 函数名?  查看源码函数名??

# %% [markdown]
# ## %timeit

# %%
# %timeit L = [i**2 for i in range(1000)]
# Out:
# 762 µs ± 110 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 983 µs ± 80.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
% time L = [i**2 for i in range(1000)]
# Out:
# Wall time: 969 µs

# %%
# wall time 人类感知时间

# %%
# %%time
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# Wall time: 998 µs

# %%
import random

# %%
L = [random.random() for i in range(1000)]
% timeit L.sort()
# Out:
# 29.9 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
L = [random.random() for i in range(1000)]
% time L.sort()
# Out:
# Wall time: 945 µs
